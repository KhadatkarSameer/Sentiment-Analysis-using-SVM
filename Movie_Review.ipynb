# %% [markdown]
# ### Import libraries

# %%
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import csr_matrix
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ### Function to make document list and seperate there labels

# %%
def initial_feature_vectors(filename):
    sentence = []
    label = []
    with open(filename, 'r') as file:
        for line in file:
            temp = line.split("\t")
            sentence.append(temp[0])
            label.append(temp[1][0])
    return sentence , label

# %% [markdown]
# ### Perform PCA function

# %%
from sklearn.decomposition import PCA

def principal_component(features,k):
    pca = PCA(n_components=k)
    pca.fit(features )
    Y = (pca.transform(features))
    return Y, pca

# %% [markdown]
# ### Read File

# %%
text_path = Path('movieReviews1000.txt')
reviews , labels = initial_feature_vectors(text_path.as_posix())

# %% [markdown]
# ### Set Train and Test Data

# %%
features_train = reviews[0:750]
features_test = reviews[750:]
labels_train = labels[0:750]
labels_test = labels[750:]

# %% [markdown]
# ### Find TF-IDF

# %%
vectorizer = TfidfVectorizer()
#Fitting on train data
vectorizer.fit(features_train) 
#Forming train and test features
Y = vectorizer.transform(features_train)
Y_test = vectorizer.transform(features_test)

# %% [markdown]
# ### Converting sparse matrix to dense matrix

# %%
from scipy.sparse import csr_matrix
Y = csr_matrix(Y)
Y = Y.todense()
Y_test = csr_matrix(Y_test)
Y_test = Y_test.todense()

# %% [markdown]
# ### Learning and Prediction using SVM model

# %%
Y, pca = principal_component(Y,10)
Y_test = (pca.transform(Y_test))

kernel = ["rbf"]
print(f'------------------------------------------------------------')
for k in kernel:
    c=0.1
    while(c<10001):
        eps = 0.0001
        while(eps<2):
            model = SVC(kernel=k,C=c,tol=eps)
            model.fit(Y,labels_train)
            print(model)
            predictions = model.predict(Y_test)
            print(f'Accuracy = {accuracy_score(labels_test,predictions)}')
            print(f'Number of support vectors for class 0 and class 1 = {model.n_support_}')
            print(f'Total Number of support vectors = {model.support_vectors_.shape[0]}')
            print(f'------------------------------------------------------------')
            eps*=10
        c*=10
# Out:
# ------------------------------------------------------------
# SVC(C=0.1, tol=0.0001)
# Accuracy = 0.532
# Number of support vectors for class 0 and class 1 = [356 347]
# Total Number of support vectors = 703
# ------------------------------------------------------------
# SVC(C=0.1)
# Accuracy = 0.532
# Number of support vectors for class 0 and class 1 = [356 347]
# Total Number of support vectors = 703
# ------------------------------------------------------------
# SVC(C=0.1, tol=0.01)
# Accuracy = 0.532
# Number of support vectors for class 0 and class 1 = [357 347]
# Total Number of support vectors = 704
# ------------------------------------------------------------
# SVC(C=0.1, tol=0.1)
# Accuracy = 0.528
# Number of support vectors for class 0 and class 1 = [347 346]
# Total Number of support vectors = 693
# ------------------------------------------------------------
# SVC(C=0.1, tol=1.0)
# Accuracy = 0.596
# Number of support vectors for class 0 and class 1 = [336 336]
# Total Number of support vectors = 672
# ------------------------------------------------------------
# SVC(tol=0.0001)
# Accuracy = 0.652
# Number of support vectors for class 0 and class 1 = [315 298]
# Total Number of support vectors = 613
# ------------------------------------------------------------
# SVC()
# Accuracy = 0.652
# Number of support vectors for class 0 and class 1 = [315 298]
# Total Number of support vectors = 613
# ------------------------------------------------------------
# SVC(tol=0.01)
# Accuracy = 0.652
# Number of support vectors for class 0 and class 1 = [313 298]
# Total Number of support vectors = 611
# ------------------------------------------------------------
# SVC(tol=0.1)
# Accuracy = 0.656
# Number of support vectors for class 0 and class 1 = [312 297]
# Total Number of support vectors = 609
# ------------------------------------------------------------
# SVC(tol=1.0)
# Accuracy = 0.648
# Number of support vectors for class 0 and class 1 = [285 284]
# Total Number of support vectors = 569
# ------------------------------------------------------------
# SVC(C=10.0, tol=0.0001)
# Accuracy = 0.656
# Number of support vectors for class 0 and class 1 = [281 273]
# Total Number of support vectors = 554
# ------------------------------------------------------------
# SVC(C=10.0)
# Accuracy = 0.656
# Number of support vectors for class 0 and class 1 = [281 273]
# Total Number of support vectors = 554
# ------------------------------------------------------------
# SVC(C=10.0, tol=0.01)
# Accuracy = 0.652
# Number of support vectors for class 0 and class 1 = [282 273]
# Total Number of support vectors = 555
# ------------------------------------------------------------
# SVC(C=10.0, tol=0.1)
# Accuracy = 0.64
# Number of support vectors for class 0 and class 1 = [282 274]
# Total Number of support vectors = 556
# ------------------------------------------------------------
# SVC(C=10.0, tol=1.0)
# Accuracy = 0.632
# Number of support vectors for class 0 and class 1 = [280 272]
# Total Number of support vectors = 552
# ------------------------------------------------------------
# SVC(C=100.0, tol=0.0001)
# Accuracy = 0.592
# Number of support vectors for class 0 and class 1 = [240 230]
# Total Number of support vectors = 470
# ------------------------------------------------------------
# SVC(C=100.0)
# Accuracy = 0.592
# Number of support vectors for class 0 and class 1 = [240 230]
# Total Number of support vectors = 470
# ------------------------------------------------------------
# SVC(C=100.0, tol=0.01)
# Accuracy = 0.592
# Number of support vectors for class 0 and class 1 = [240 231]
# Total Number of support vectors = 471
# ------------------------------------------------------------
# SVC(C=100.0, tol=0.1)
# Accuracy = 0.588
# Number of support vectors for class 0 and class 1 = [240 234]
# Total Number of support vectors = 474
# ------------------------------------------------------------
# SVC(C=100.0, tol=1.0)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [265 251]
# Total Number of support vectors = 516
# ------------------------------------------------------------
# SVC(C=1000.0, tol=0.0001)
# Accuracy = 0.592
# Number of support vectors for class 0 and class 1 = [215 206]
# Total Number of support vectors = 421
# ------------------------------------------------------------
# SVC(C=1000.0)
# Accuracy = 0.592
# Number of support vectors for class 0 and class 1 = [215 206]
# Total Number of support vectors = 421
# ------------------------------------------------------------
# SVC(C=1000.0, tol=0.01)
# Accuracy = 0.592
# Number of support vectors for class 0 and class 1 = [214 206]
# Total Number of support vectors = 420
# ------------------------------------------------------------
# SVC(C=1000.0, tol=0.1)
# Accuracy = 0.58
# Number of support vectors for class 0 and class 1 = [216 208]
# Total Number of support vectors = 424
# ------------------------------------------------------------
# SVC(C=1000.0, tol=1.0)
# Accuracy = 0.596
# Number of support vectors for class 0 and class 1 = [226 225]
# Total Number of support vectors = 451
# ------------------------------------------------------------
# SVC(C=10000.0, tol=0.0001)
# Accuracy = 0.56
# Number of support vectors for class 0 and class 1 = [191 185]
# Total Number of support vectors = 376
# ------------------------------------------------------------
# SVC(C=10000.0)
# Accuracy = 0.56
# Number of support vectors for class 0 and class 1 = [191 185]
# Total Number of support vectors = 376
# ------------------------------------------------------------
# SVC(C=10000.0, tol=0.01)
# Accuracy = 0.56
# Number of support vectors for class 0 and class 1 = [191 185]
# Total Number of support vectors = 376
# ------------------------------------------------------------
# SVC(C=10000.0, tol=0.1)
# Accuracy = 0.56
# Number of support vectors for class 0 and class 1 = [192 187]
# Total Number of support vectors = 379
# ------------------------------------------------------------
# SVC(C=10000.0, tol=1.0)
# Accuracy = 0.58
# Number of support vectors for class 0 and class 1 = [204 199]
# Total Number of support vectors = 403
# ------------------------------------------------------------

# %%
kernel = ["poly"]
print(f'------------------------------------------------------------')
for k in kernel:
    c=0.1
    while(c<10001):
        eps = 0.0001
        while(eps<2):
            model = SVC(kernel=k,C=c,tol=eps)
            model.fit(Y,labels_train)
            print(model)
            predictions = model.predict(Y_test)
            print(f'Accuracy = {accuracy_score(labels_test,predictions)}')
            print(f'Number of support vectors for class 0 and class 1 = {model.n_support_}')
            print(f'Total Number of support vectors = {model.support_vectors_.shape[0]}')
            print(f'------------------------------------------------------------')
            eps*=10
        c*=10
# Out:
# ------------------------------------------------------------
# SVC(C=0.1, kernel='poly', tol=0.0001)
# Accuracy = 0.412
# Number of support vectors for class 0 and class 1 = [342 333]
# Total Number of support vectors = 675
# ------------------------------------------------------------
# SVC(C=0.1, kernel='poly')
# Accuracy = 0.412
# Number of support vectors for class 0 and class 1 = [342 333]
# Total Number of support vectors = 675
# ------------------------------------------------------------
# SVC(C=0.1, kernel='poly', tol=0.01)
# Accuracy = 0.412
# Number of support vectors for class 0 and class 1 = [342 333]
# Total Number of support vectors = 675
# ------------------------------------------------------------
# SVC(C=0.1, kernel='poly', tol=0.1)
# Accuracy = 0.412
# Number of support vectors for class 0 and class 1 = [342 332]
# Total Number of support vectors = 674
# ------------------------------------------------------------
# SVC(C=0.1, kernel='poly', tol=1.0)
# Accuracy = 0.42
# Number of support vectors for class 0 and class 1 = [337 329]
# Total Number of support vectors = 666
# ------------------------------------------------------------
# SVC(kernel='poly', tol=0.0001)
# Accuracy = 0.468
# Number of support vectors for class 0 and class 1 = [313 310]
# Total Number of support vectors = 623
# ------------------------------------------------------------
# SVC(kernel='poly')
# Accuracy = 0.468
# Number of support vectors for class 0 and class 1 = [313 310]
# Total Number of support vectors = 623
# ------------------------------------------------------------
# SVC(kernel='poly', tol=0.01)
# Accuracy = 0.468
# Number of support vectors for class 0 and class 1 = [313 310]
# Total Number of support vectors = 623
# ------------------------------------------------------------
# SVC(kernel='poly', tol=0.1)
# Accuracy = 0.472
# Number of support vectors for class 0 and class 1 = [312 311]
# Total Number of support vectors = 623
# ------------------------------------------------------------
# SVC(kernel='poly', tol=1.0)
# Accuracy = 0.544
# Number of support vectors for class 0 and class 1 = [314 308]
# Total Number of support vectors = 622
# ------------------------------------------------------------
# SVC(C=10.0, kernel='poly', tol=0.0001)
# Accuracy = 0.6
# Number of support vectors for class 0 and class 1 = [273 274]
# Total Number of support vectors = 547
# ------------------------------------------------------------
# SVC(C=10.0, kernel='poly')
# Accuracy = 0.6
# Number of support vectors for class 0 and class 1 = [273 274]
# Total Number of support vectors = 547
# ------------------------------------------------------------
# SVC(C=10.0, kernel='poly', tol=0.01)
# Accuracy = 0.6
# Number of support vectors for class 0 and class 1 = [273 274]
# Total Number of support vectors = 547
# ------------------------------------------------------------
# SVC(C=10.0, kernel='poly', tol=0.1)
# Accuracy = 0.6
# Number of support vectors for class 0 and class 1 = [272 271]
# Total Number of support vectors = 543
# ------------------------------------------------------------
# SVC(C=10.0, kernel='poly', tol=1.0)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [277 274]
# Total Number of support vectors = 551
# ------------------------------------------------------------
# SVC(C=100.0, kernel='poly', tol=0.0001)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [231 228]
# Total Number of support vectors = 459
# ------------------------------------------------------------
# SVC(C=100.0, kernel='poly')
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [231 228]
# Total Number of support vectors = 459
# ------------------------------------------------------------
# SVC(C=100.0, kernel='poly', tol=0.01)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [231 228]
# Total Number of support vectors = 459
# ------------------------------------------------------------
# SVC(C=100.0, kernel='poly', tol=0.1)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [233 225]
# Total Number of support vectors = 458
# ------------------------------------------------------------
# SVC(C=100.0, kernel='poly', tol=1.0)
# Accuracy = 0.632
# Number of support vectors for class 0 and class 1 = [243 240]
# Total Number of support vectors = 483
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='poly', tol=0.0001)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [196 197]
# Total Number of support vectors = 393
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='poly')
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [195 197]
# Total Number of support vectors = 392
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='poly', tol=0.01)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [195 196]
# Total Number of support vectors = 391
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='poly', tol=0.1)
# Accuracy = 0.596
# Number of support vectors for class 0 and class 1 = [199 198]
# Total Number of support vectors = 397
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='poly', tol=1.0)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [208 202]
# Total Number of support vectors = 410
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='poly', tol=0.0001)
# Accuracy = 0.6
# Number of support vectors for class 0 and class 1 = [177 179]
# Total Number of support vectors = 356
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='poly')
# Accuracy = 0.6
# Number of support vectors for class 0 and class 1 = [177 179]
# Total Number of support vectors = 356
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='poly', tol=0.01)
# Accuracy = 0.6
# Number of support vectors for class 0 and class 1 = [177 178]
# Total Number of support vectors = 355
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='poly', tol=0.1)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [180 183]
# Total Number of support vectors = 363
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='poly', tol=1.0)
# Accuracy = 0.612
# Number of support vectors for class 0 and class 1 = [186 187]
# Total Number of support vectors = 373
# ------------------------------------------------------------

# %%
kernel = ["linear"]
print(f'------------------------------------------------------------')
for k in kernel:
    c=0.1
    while(c<10001):
        eps = 0.0001
        while(eps<2):
            model = SVC(kernel=k,C=c,tol=eps)
            model.fit(Y,labels_train)
            print(model)
            predictions = model.predict(Y_test)
            print(f'Accuracy = {accuracy_score(labels_test,predictions)}')
            print(f'Number of support vectors for class 0 and class 1 = {model.n_support_}')
            print(f'Total Number of support vectors = {model.support_vectors_.shape[0]}')
            print(f'------------------------------------------------------------')
            eps*=10
        c*=10
# Out:
# ------------------------------------------------------------
# SVC(C=0.1, kernel='linear', tol=0.0001)
# Accuracy = 0.388
# Number of support vectors for class 0 and class 1 = [350 347]
# Total Number of support vectors = 697
# ------------------------------------------------------------
# SVC(C=0.1, kernel='linear')
# Accuracy = 0.388
# Number of support vectors for class 0 and class 1 = [351 347]
# Total Number of support vectors = 698
# ------------------------------------------------------------
# SVC(C=0.1, kernel='linear', tol=0.01)
# Accuracy = 0.388
# Number of support vectors for class 0 and class 1 = [350 347]
# Total Number of support vectors = 697
# ------------------------------------------------------------
# SVC(C=0.1, kernel='linear', tol=0.1)
# Accuracy = 0.388
# Number of support vectors for class 0 and class 1 = [347 347]
# Total Number of support vectors = 694
# ------------------------------------------------------------
# SVC(C=0.1, kernel='linear', tol=1.0)
# Accuracy = 0.388
# Number of support vectors for class 0 and class 1 = [347 347]
# Total Number of support vectors = 694
# ------------------------------------------------------------
# SVC(kernel='linear', tol=0.0001)
# Accuracy = 0.532
# Number of support vectors for class 0 and class 1 = [331 331]
# Total Number of support vectors = 662
# ------------------------------------------------------------
# SVC(kernel='linear')
# Accuracy = 0.532
# Number of support vectors for class 0 and class 1 = [331 331]
# Total Number of support vectors = 662
# ------------------------------------------------------------
# SVC(kernel='linear', tol=0.01)
# Accuracy = 0.536
# Number of support vectors for class 0 and class 1 = [331 330]
# Total Number of support vectors = 661
# ------------------------------------------------------------
# SVC(kernel='linear', tol=0.1)
# Accuracy = 0.536
# Number of support vectors for class 0 and class 1 = [329 329]
# Total Number of support vectors = 658
# ------------------------------------------------------------
# SVC(kernel='linear', tol=1.0)
# Accuracy = 0.572
# Number of support vectors for class 0 and class 1 = [319 319]
# Total Number of support vectors = 638
# ------------------------------------------------------------
# SVC(C=10.0, kernel='linear', tol=0.0001)
# Accuracy = 0.612
# Number of support vectors for class 0 and class 1 = [303 301]
# Total Number of support vectors = 604
# ------------------------------------------------------------
# SVC(C=10.0, kernel='linear')
# Accuracy = 0.612
# Number of support vectors for class 0 and class 1 = [303 301]
# Total Number of support vectors = 604
# ------------------------------------------------------------
# SVC(C=10.0, kernel='linear', tol=0.01)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [303 301]
# Total Number of support vectors = 604
# ------------------------------------------------------------
# SVC(C=10.0, kernel='linear', tol=0.1)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [304 302]
# Total Number of support vectors = 606
# ------------------------------------------------------------
# SVC(C=10.0, kernel='linear', tol=1.0)
# Accuracy = 0.612
# Number of support vectors for class 0 and class 1 = [300 298]
# Total Number of support vectors = 598
# ------------------------------------------------------------
# SVC(C=100.0, kernel='linear', tol=0.0001)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [298 295]
# Total Number of support vectors = 593
# ------------------------------------------------------------
# SVC(C=100.0, kernel='linear')
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [298 295]
# Total Number of support vectors = 593
# ------------------------------------------------------------
# SVC(C=100.0, kernel='linear', tol=0.01)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [298 295]
# Total Number of support vectors = 593
# ------------------------------------------------------------
# SVC(C=100.0, kernel='linear', tol=0.1)
# Accuracy = 0.612
# Number of support vectors for class 0 and class 1 = [301 296]
# Total Number of support vectors = 597
# ------------------------------------------------------------
# SVC(C=100.0, kernel='linear', tol=1.0)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [309 301]
# Total Number of support vectors = 610
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='linear', tol=0.0001)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [297 294]
# Total Number of support vectors = 591
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='linear')
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [297 294]
# Total Number of support vectors = 591
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='linear', tol=0.01)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [297 294]
# Total Number of support vectors = 591
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='linear', tol=0.1)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [302 296]
# Total Number of support vectors = 598
# ------------------------------------------------------------
# SVC(C=1000.0, kernel='linear', tol=1.0)
# Accuracy = 0.616
# Number of support vectors for class 0 and class 1 = [309 302]
# Total Number of support vectors = 611
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='linear', tol=0.0001)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [296 294]
# Total Number of support vectors = 590
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='linear')
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [296 294]
# Total Number of support vectors = 590
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='linear', tol=0.01)
# Accuracy = 0.608
# Number of support vectors for class 0 and class 1 = [298 294]
# Total Number of support vectors = 592
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='linear', tol=0.1)
# Accuracy = 0.612
# Number of support vectors for class 0 and class 1 = [304 296]
# Total Number of support vectors = 600
# ------------------------------------------------------------
# SVC(C=10000.0, kernel='linear', tol=1.0)
# Accuracy = 0.604
# Number of support vectors for class 0 and class 1 = [311 301]
# Total Number of support vectors = 612
# ------------------------------------------------------------
